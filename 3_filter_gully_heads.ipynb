# %% [markdown]
# ## Import required libraries.

# %%
# %%capture
import operator
import seaborn as sns; sns.set()
from jupyterthemes import jtplot
jtplot.style()
import numpy as np
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy.signal import medfilt
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure

# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120) 
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Setup input data
# Define spatial resolution: Specify the resolution of the input DEM and also the desired working resolution (can be same as input DEM resolution).

# %%
def roundup(x):
    return int(math.ceil(x / 10.0)) * 10

input_DEM_resolution = 1
working_resolution = 1
location = (r'C:\PhD\junk')
os.chdir(location)
input_geotiff = gdal.Open('bogie_s_1.tif')
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
empty_grid_rows = roundup(x.shape[0])
empty_grid_cols = roundup(x.shape[1])
input_DEM = np.zeros([empty_grid_rows,empty_grid_cols])
input_DEM[:x.shape[0], :x.shape[1]] = x

input_outlets = gdal.Open('bogie_5md.tif')
o = np.array(input_outlets.GetRasterBand(1).ReadAsArray())
outlets= o
#outlets = 1 - o

# %% [markdown]
# ## Visualise the DEM.

# %%
plt.figure(figsize=(12,12))
plt.imshow(input_DEM, cmap="terrain_r", vmin = np.percentile(input_DEM, 5));
plt.colorbar();

# %% [markdown]
# ## Define required function.

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def differenceFromMeanElevation(elev):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = elev[central_value]                        
    mean = np.nanmean(elev)#Count number of values greater than centroid value
    diff = centroid - mean
    return diff
def PCTL(x):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = x[central_value]                        
    y = np.sum(x < centroid)/num_values#Count number of values greater than centroid value
    return y
def flow_dir_dataset(flow_rec_prop, catchment_area, grid_resolution, outlet_node):
    """ Create an xarray Dataset containing eight arrays each representing the
    amount of water flowing in the given direction.
        1 . flow_rec_prop == the flow receiver proportion array created by LandLab flow routing.
        2 . catchment_area == the corresponding catchment area array from the landLab flow accumulation.
        surface.        
    The resulting Dataset is used to calculate specific catchment area."""
    array_direction = xr.Dataset()
    for i in range(0,8):
        rows = catchment_area.shape[0]; cols = catchment_area.shape[1];
        direction = np.flip(flow_rec_prop[:,i].reshape(rows,cols), 0);
        # Above needs to be flipped because during reshape it organises data top down
        # rather than bottom up as per ModelGrid order (catchment_area is mg arrangement).
        zero_outlet = outlet_node != 1
        remove_outlet = zero_outlet * catchment_area
        weighted_direction = xr.DataArray((remove_outlet * direction),
                                          dims = ['lat', 'lon']);
        array_direction[direction_list[i]] = weighted_direction
        
    E, N, W, S, NE, NW, SW, SE = (array_direction['East'], array_direction['North'],
                             array_direction['West'], array_direction['South'],
                             array_direction['North East'], array_direction['North West'],
                             array_direction['South West'], array_direction['South East'])

    flow_dirs = xr.concat([E, N, W, S, NE, NW, SW, SE], 'direction')
    flow_dirs.name = 'flow_directions'
    flow_dirs.attrs['grid cell resolution'] = grid_resolution
    flow_directions = flow_dirs.assign_coords(direction=(['East','North','West','South',
                                   'North East', 'North West','South West', 'South East']))
    return flow_directions
def profileCurvature(DEM, cellsize):
    """This process is taken from Change (2014, Introduction to Geographic Information
       systems, Page 284)."""
    Z1 = DEM[0]; Z2 = DEM[1]; Z3 = DEM[2]
    Z4 = DEM[3]; Z0 = DEM[4]; Z5 = DEM[5]
    Z6 = DEM[6]; Z7 = DEM[7]; Z8 = DEM[8]
    D = (((Z4 + Z5)/2) - Z0) / cellsize**2
    E = (((Z2 + Z7)/2) - Z0) / cellsize**2
    F = (Z3 - Z1 + Z6 - Z8)/ (4 * cellsize**2)
    G = (Z5 - Z4) / (2 * cellsize)
    H = (Z2 - Z7) / (2 * cellsize)
    profile_curvature = (-2 * (D*(G**2) + E*(H**2) + (F*G*H))) / (G**2 + H**2)
    return profile_curvature
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def closest(lst, K): 
     angle_list = lst
     idx = (np.abs(angle_list - K)).argmin() 
     return angle_list[idx]  
def data_range(data):
    data_min = np.amin(data); data_max = np.amax(data)
    value_range = data_max - data_min
    return value_range
def checkGullyHead(dfme_list, step_size, comparison_distance, minimum_depth, elevation_of_gh):
    
    """ """
    max_value_length = len(dfme_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = dfme_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = dfme_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        min_downstream = np.min(downstream_nodes)
        mean_upstream = np.mean(upstream_nodes)
        std_upstream = np.std(upstream_nodes)
        elevation_difference = min_downstream - mean_upstream
        print('minimum downstream value: ', min_downstream)
        print('mean upstream value: ', mean_upstream)
        print('std upstream value: ', std_upstream)
      
        if min_downstream <= minimum_depth and mean_upstream > elevation_of_gh and std_upstream < 0.1 and elevation_difference <= -0.2:
            keep_gully = 'yes'
            # below could use either floor or ceil instead of round 
            gully_head_location = int(end_of_downstream_nodes + np.round(comparison_distance/2))
            break
        else:
            keep_gully = 'no'
            gully_head_location = 'none'

    return keep_gully, gully_head_location
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    final_gully_head_position_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    is_gully_head = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    gully_head_node_dict = {}
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
        
        grid_nodes_subset = grid_nodes[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        
        flattened_grid_nodes_subset = grid_nodes_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        original_node_id_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            upstream_original_node_id = {}
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        original_node_id = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_grid_nodes_subset))
                        upstream_original_node_id.update({node_id_value:original_node_id})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    print(primary_flow_direction_id)
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    original_node_id_dict[primary_flow_direction_id] = upstream_original_node_id[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)

        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        original_node_id_along_central_drainage_line = []
        for key, value in original_node_id_dict.items():
            original_node_id_along_central_drainage_line.append(value)
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            is_gully_head[i] = 'not enough grid cells'
        else:
            print('node: ',i,)
            divergence_occuring, gully_head_node = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            is_gully_head[i] = divergence_occuring
            gully_head_node_dict[i] = gully_head_node
            if isinstance(gully_head_node, str):
                pass
            else:
                final_gully_head_position_dict[i] = original_node_id_along_central_drainage_line[gully_head_node]
                
    return final_gully_head_position_dict, is_gully_head, slope_dict, slope_at_head

# %%
#################################################################################################
flow_acc_surf = np.copy(input_DEM).astype('float64');
#################################################################################################
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorMFD',
                    diagonals = True);
#(flow_acc, q) = fa.accumulate_flow();
fa.run_one_step()
fd = FlowDirectorMFD(mg, 'topographic__elevation', diagonals = True);
fd.run_one_step()

da = np.array(mg.at_node['drainage_area'].round(4));
catchment_area_ha = np.divide(da.reshape(mg.shape), (100/working_resolution)**2)
frn = mg.at_node['flow__receiver_node'];
drainage_area = np.flip(da.reshape(mg.shape), 0);
frp = np.array(mg.at_node['flow__receiver_proportions']);
ns = np.flip(mg.status_at_node.reshape(mg.shape), 0);
flow_rec_surf_rows = cols * rows;
flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);

tss = mg.at_node['topographic__steepest_slope'];
steepest_slope = tss.reshape(flow_rec_surf_rows,8);
all_receiver_proportions = np.copy(frp);

# %% [markdown]
# # For all nodes

# %%
# Must be larger than 'line_length' (specified later).
size_of_edge = 30

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))
find_nodes = np.multiply(outlets, grid_nodes);

gully_head_edge_mask = np.zeros([grid_nodes.shape[0], grid_nodes.shape[1]])
gully_head_mask_centre = np.ones([grid_nodes.shape[0] - size_of_edge*2, grid_nodes.shape[1] - size_of_edge*2])
gully_head_edge_mask[size_of_edge:-1*(size_of_edge), size_of_edge:-1*(size_of_edge)] = gully_head_mask_centre

remaining_gully_heads = find_nodes * gully_head_edge_mask
gh_array = np.unique(remaining_gully_heads).astype(int);
gh_list = gh_array.tolist();
gh_list.remove(0);
len(gh_list)
# Out:
# 77

# %% [markdown]
# # For one node

# %%
#grid_nodes = np.array(mg.nodes.reshape(mg.shape))
#find_outlet_ids = grid_nodes * outlets
#outlet_id = np.unique(find_outlet_ids)[1]

# %%
radius = 9
central_value = find_median_value(circleWindow(radius))
num_values = number_of_values(circleWindow(radius))
dfme = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(radius), mode='nearest');
dfme[dfme > 5.0] = 5.0
dfme[dfme < -5.0] = -5.0

# %%
slope = generic_filter(input_DEM, slopeWindowDegrees,
                  footprint= rectangleWindow(3,3),
                  mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

# %%
shape = 9
central_value = find_median_value(circleWindow(shape))
num_values = number_of_values(circleWindow(shape))

# %%
DFME = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(shape), mode='nearest');

# %%
# Specific the size of the area to be checked. This represents a physical distance from the 
# outlet but has no unit of measure.
distance_from_outlet = 20

# %% [markdown]
# ## Currently using 10m upstream from the point 5 m downstream of the initial gully head.

# %%
final_gully_heads, gully_head_dict, slope_dict, slope_area_data = upstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,gh_list, 3, 3, 10, -0.2, -0.2)
# Out:
# 840
# (41, 41)
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 767
# 768
# 769
# 10   10
# 811
# 771
# 731
# 690
# 650
# 651
# 611
# 570
# 530
# node:  320908
# minimum downstream value:  -0.633571368432
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 801
# 802
# 803
# 804
# 764
# 765
# 766
# 767
# 727
# 769
# 10   10
# 729
# 730
# 731
# 691
# 651
# 611
# 571
# 572
# 613
# node:  325215
# minimum downstream value:  -1.01409103936
# mean upstream value:  -0.0148309800622
# std upstream value:  0.0151195469607
# 840
# (41, 41)
# 800
# 801
# 761
# 721
# 681
# 640
# 600
# 601
# 602
# 644
# 604
# 10   10
# 646
# 606
# 648
# 690
# 732
# 733
# 734
# 735
# 736
# node:  413660
# minimum downstream value:  -0.40042141398
# mean upstream value:  -0.0672884251289
# std upstream value:  0.0291409575205
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 804
# 764
# 724
# 725
# 685
# 645
# 605
# 10   10
# 564
# 524
# 525
# 526
# 568
# 528
# 570
# 530
# 572
# node:  416514
# minimum downstream value:  -0.521983180593
# mean upstream value:  -0.360267277292
# std upstream value:  0.029650524636
# minimum downstream value:  -0.498118163098
# mean upstream value:  -0.385278091129
# std upstream value:  0.0406115752443
# minimum downstream value:  -0.434442301513
# mean upstream value:  -0.447572459345
# std upstream value:  0.0498951081862
# minimum downstream value:  -0.416924819645
# mean upstream value:  -0.351129021726
# std upstream value:  0.173744101901
# minimum downstream value:  -0.416924819645
# mean upstream value:  -0.223589147032
# std upstream value:  0.209050442728
# minimum downstream value:  -0.350652732397
# mean upstream value:  -0.0874769791313
# std upstream value:  0.0314246707839
# 840
# (41, 41)
# 841
# 842
# 884
# 926
# 968
# 969
# 1011
# 1052
# 1094
# 1134
# 1176
# 10   10
# 1216
# 1257
# 1298
# 1339
# 1380
# 1421
# 1463
# 1464
# 1465
# node:  486729
# minimum downstream value:  -0.502186047701
# mean upstream value:  -0.278425646394
# std upstream value:  0.0072857402528
# minimum downstream value:  -0.48820751929
# mean upstream value:  -0.232028393249
# std upstream value:  0.0680522964086
# minimum downstream value:  -0.420874403399
# mean upstream value:  -0.173477605083
# std upstream value:  0.0698624035854
# 840
# (41, 41)
# 841
# 842
# 843
# 802
# 761
# 721
# 681
# 641
# 601
# 561
# 520
# 10   10
# 521
# 522
# 482
# 442
# 401
# 361
# 321
# 322
# 323
# node:  509646
# minimum downstream value:  -0.381099806473
# mean upstream value:  -0.741096556893
# std upstream value:  0.03853469426
# minimum downstream value:  -0.417897522214
# mean upstream value:  -0.76215991798
# std upstream value:  0.0133698678547
# minimum downstream value:  -0.475472371098
# mean upstream value:  -0.697716452859
# std upstream value:  0.0981789431589
# minimum downstream value:  -0.573769671172
# mean upstream value:  -0.543792423052
# std upstream value:  0.17710848175
# minimum downstream value:  -0.689027477159
# mean upstream value:  -0.293053236246
# std upstream value:  0.229318544828
# minimum downstream value:  -0.753202988696
# mean upstream value:  -0.106429038469
# std upstream value:  0.150513389633
# minimum downstream value:  -0.781059204825
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 760
# 720
# 680
# 640
# 641
# 642
# 602
# 562
# 521
# 481
# 10   10
# 440
# 400
# 360
# 320
# 280
# 240
# 199
# 158
# 118
# node:  554171
# minimum downstream value:  -0.469888589128
# mean upstream value:  -0.103536331921
# std upstream value:  0.0277282844205
# 840
# (41, 41)
# 881
# 923
# 964
# 1004
# 1045
# 1086
# 1127
# 1168
# 1208
# 1249
# 1290
# 10   10
# 1330
# 1371
# 1412
# 1453
# 1494
# 1534
# 1576
# 1617
# 1618
# node:  565479
# minimum downstream value:  -1.08368073716
# mean upstream value:  -0.0848438931391
# std upstream value:  0.0295920056229
# 840
# (41, 41)
# 800
# 801
# 761
# 721
# 722
# 764
# 765
# 807
# 849
# 890
# 932
# 10   10
# 974
# 1016
# 1017
# 1059
# 1101
# 1102
# 1103
# 1104
# 1105
# node:  567093
# minimum downstream value:  -1.21654480342
# mean upstream value:  -0.0410461727338
# std upstream value:  0.00578374327011
# 840
# (41, 41)
# 800
# 801
# 760
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# 686
# 10   10
# 646
# 606
# 566
# 526
# 485
# 445
# 405
# 365
# 325
# node:  568456
# minimum downstream value:  -1.016952002
# mean upstream value:  -0.0741185023693
# std upstream value:  0.0174388600125
# 840
# (41, 41)
# 882
# 924
# 925
# 967
# 1009
# 1010
# 1052
# 1094
# 1095
# 1096
# 1138
# 10   10
# 1180
# 1222
# 1223
# 1264
# 1306
# 1348
# 1390
# 1432
# 1473
# node:  572542
# minimum downstream value:  -0.444957687921
# mean upstream value:  -0.394537502284
# std upstream value:  0.0453869691069
# minimum downstream value:  -0.442090663985
# mean upstream value:  -0.365729039209
# std upstream value:  0.00516691724533
# minimum downstream value:  -0.439981091164
# mean upstream value:  -0.361606944691
# std upstream value:  0.00795626242615
# minimum downstream value:  -0.439981091164
# mean upstream value:  -0.358735910046
# std upstream value:  0.00956596540564
# minimum downstream value:  -0.458635594063
# mean upstream value:  -0.355057506536
# std upstream value:  0.00440921902385
# minimum downstream value:  -0.458635594063
# mean upstream value:  -0.338748705717
# std upstream value:  0.024840424323
# minimum downstream value:  -0.458635594063
# mean upstream value:  -0.254930146912
# std upstream value:  0.112348974889
# minimum downstream value:  -0.372210204837
# mean upstream value:  -0.153606238887
# std upstream value:  0.107819638947
# minimum downstream value:  -0.372210204837
# mean upstream value:  -0.0766199184815
# std upstream value:  0.0174389146534
# 840
# (41, 41)
# 841
# 883
# 925
# 967
# 968
# 1009
# 1051
# 1093
# 1135
# 1177
# 1218
# 10   10
# 1260
# 1301
# 1302
# 1344
# 1384
# 1425
# 1467
# 1468
# 1510
# node:  581131
# minimum downstream value:  -0.372210204837
# mean upstream value:  -0.0643854957952
# std upstream value:  0.00661056688707
# 840
# (41, 41)
# 841
# 842
# 884
# 844
# 845
# 846
# 847
# 848
# 849
# 891
# 933
# 10   10
# 975
# 1017
# 1018
# 1060
# 1102
# 1144
# 1145
# 1187
# 1228
# node:  585687
# minimum downstream value:  -1.5115238838
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 921
# 962
# 1002
# 1043
# 1085
# 1126
# 1167
# 1209
# 1250
# 1291
# 10   10
# 1332
# 1333
# 1375
# 1417
# 1418
# 1419
# 1420
# 1462
# 1504
# node:  595681
# minimum downstream value:  -1.1600870728
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 924
# 966
# 1008
# 1050
# 1092
# 1134
# 1176
# 1177
# 1178
# 1220
# 10   10
# 1262
# 1263
# 1305
# 1265
# 1307
# 1349
# 1390
# 1432
# 1474
# node:  598545
# minimum downstream value:  -1.27079492501
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 923
# 965
# 966
# 967
# 968
# 969
# 970
# 1012
# 1053
# 1094
# 10   10
# 1135
# 1177
# 1219
# 1220
# 1262
# 1263
# 1305
# 1346
# 1388
# node:  619970
# minimum downstream value:  -0.77069224482
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 880
# 920
# 961
# 1002
# 1043
# 1084
# 1124
# 1165
# 1205
# 1246
# 10   10
# 1286
# 1287
# 1245
# 1203
# 1161
# 1119
# 1118
# 1117
# 1116
# node:  821130
# minimum downstream value:  -0.440037210939
# mean upstream value:  -0.323095932308
# std upstream value:  0.0215180353393
# minimum downstream value:  -0.440037210939
# mean upstream value:  -0.357708072788
# std upstream value:  0.0296001333893
# minimum downstream value:  -0.347945232165
# mean upstream value:  -0.362543581032
# std upstream value:  0.0253110561245
# minimum downstream value:  -0.34166108384
# mean upstream value:  -0.379263554951
# std upstream value:  0.025634440753
# minimum downstream value:  -0.34166108384
# mean upstream value:  -0.349633982059
# std upstream value:  0.0358546070991
# minimum downstream value:  -0.34166108384
# mean upstream value:  -0.331823517368
# std upstream value:  0.0464258300447
# minimum downstream value:  -0.346316281043
# mean upstream value:  -0.262678535874
# std upstream value:  0.0526934260728
# minimum downstream value:  -0.398288380016
# mean upstream value:  -0.205875230872
# std upstream value:  0.0626258683754
# minimum downstream value:  -0.398288380016
# mean upstream value:  -0.147101109521
# std upstream value:  0.0314597999028
# 840
# (41, 41)
# 881
# 922
# 963
# 1004
# 1045
# 1086
# 1127
# 1168
# 1209
# 1251
# 1292
# 10   10
# 1333
# 1375
# 1415
# 1457
# 1497
# 1538
# 1580
# 1622
# 1623
# node:  835453
# minimum downstream value:  -0.346934774648
# mean upstream value:  -0.0769716747822
# std upstream value:  0.0204494854706
# 840
# (41, 41)
# 881
# 922
# 962
# 1003
# 1043
# 1084
# 1125
# 1166
# 1206
# 1247
# 1288
# 10   10
# 1329
# 1369
# 1368
# 1367
# 1366
# 1365
# 1323
# 1322
# 1280
# node:  874037
# minimum downstream value:  -0.372494452556
# mean upstream value:  -0.332896980215
# std upstream value:  0.0043181625514
# minimum downstream value:  -0.311749183142
# mean upstream value:  -0.337062398436
# std upstream value:  0.00805616176137
# minimum downstream value:  -0.336274128186
# mean upstream value:  -0.346025640314
# std upstream value:  0.00679333203761
# minimum downstream value:  -0.336274128186
# mean upstream value:  -0.348783510633
# std upstream value:  0.00367839116543
# minimum downstream value:  -0.336274128186
# mean upstream value:  -0.342907238384
# std upstream value:  0.010302272303
# minimum downstream value:  -0.334283851352
# mean upstream value:  -0.329409683489
# std upstream value:  0.0131376673112
# minimum downstream value:  -0.337354004147
# mean upstream value:  -0.297038122285
# std upstream value:  0.0349060842865
# minimum downstream value:  -0.346780106013
# mean upstream value:  -0.257365280775
# std upstream value:  0.042641086516
# minimum downstream value:  -0.353942810782
# mean upstream value:  -0.218060429388
# std upstream value:  0.0223425681405
# minimum downstream value:  -0.353942810782
# mean upstream value:  -0.135222785558
# std upstream value:  0.0958024727025
# 840
# (41, 41)
# 839
# 838
# 837
# 877
# 876
# 875
# 874
# 914
# 872
# 871
# 911
# 10   10
# 910
# 950
# 949
# 989
# 1029
# 1028
# 1068
# 1067
# 1026
# node:  945521
# minimum downstream value:  -0.359807674121
# mean upstream value:  -0.0580691813794
# std upstream value:  0.0124933997779
# 840
# (41, 41)
# 841
# 842
# 843
# 803
# 804
# 805
# 806
# 766
# 767
# 727
# 728
# 10   10
# 729
# 730
# 690
# 650
# 610
# 611
# 571
# 613
# 572
# node:  957407
# minimum downstream value:  -0.400401209654
# mean upstream value:  -0.254505142393
# std upstream value:  0.0827019876488
# minimum downstream value:  -0.400401209654
# mean upstream value:  -0.161480306794
# std upstream value:  0.0796969752975
# 840
# (41, 41)
# 841
# 842
# 802
# 803
# 804
# 805
# 765
# 766
# 726
# 727
# 728
# 10   10
# 729
# 689
# 649
# 609
# 610
# 570
# 612
# 613
# 572
# node:  957408
# minimum downstream value:  -0.400401209654
# mean upstream value:  -0.161480306794
# std upstream value:  0.0796969752975
# 840
# (41, 41)
# 839
# 838
# 837
# 836
# 835
# 875
# 874
# 832
# 831
# 830
# 870
# 10   10
# 911
# 951
# 991
# 990
# 1030
# 1029
# 1028
# 1027
# 1067
# node:  981264
# minimum downstream value:  -0.611635381525
# mean upstream value:  -0.307546985008
# std upstream value:  0.0857656467185
# minimum downstream value:  -0.611635381525
# mean upstream value:  -0.353298644617
# std upstream value:  0.060051141802
# minimum downstream value:  -0.558784062683
# mean upstream value:  -0.412685037445
# std upstream value:  0.0406757534423
# minimum downstream value:  -0.558784062683
# mean upstream value:  -0.377658567567
# std upstream value:  0.0573721727189
# minimum downstream value:  -0.402757697426
# mean upstream value:  -0.328307421939
# std upstream value:  0.100478000745
# minimum downstream value:  -0.277480687077
# mean upstream value:  -0.176427466753
# std upstream value:  0.132485389939
# minimum downstream value:  -0.42434276234
# mean upstream value:  -0.0700063491841
# std upstream value:  0.0990039284684
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 886
# 887
# 847
# 889
# 930
# 972
# 1014
# 10   10
# 1015
# 1016
# 1017
# 1018
# 1060
# 1061
# 1102
# 1142
# 1184
# node:  1004150
# minimum downstream value:  -0.556823941559
# mean upstream value:  -0.258025228427
# std upstream value:  0.0369810377535
# minimum downstream value:  -0.556823941559
# mean upstream value:  -0.240061391798
# std upstream value:  0.0309958735126
# minimum downstream value:  -0.495446306915
# mean upstream value:  -0.241693056933
# std upstream value:  0.0331565343468
# minimum downstream value:  -0.441734555211
# mean upstream value:  -0.257518029496
# std upstream value:  0.0215872960849
# minimum downstream value:  -0.441734555211
# mean upstream value:  -0.234016559184
# std upstream value:  0.0519927326009
# minimum downstream value:  -0.441734555211
# mean upstream value:  -0.190860311033
# std upstream value:  0.0442559631295
# 840
# (41, 41)
# 881
# 921
# 920
# 919
# 918
# 917
# 875
# 874
# 873
# 831
# 830
# 10   10
# 829
# 787
# 786
# 826
# 825
# 824
# 865
# 905
# 946
# node:  1018442
# minimum downstream value:  -0.674944187813
# mean upstream value:  -0.267558352906
# std upstream value:  0.0281618413013
# minimum downstream value:  -0.674944187813
# mean upstream value:  -0.243456170807
# std upstream value:  0.0121139234825
# minimum downstream value:  -0.674944187813
# mean upstream value:  -0.157523877693
# std upstream value:  0.109564728549
# minimum downstream value:  -0.554977718549
# mean upstream value:  -0.0784532046915
# std upstream value:  0.10911820413
# minimum downstream value:  -0.529819925783
# mean upstream value:  -0.000865750319088
# std upstream value:  0.00122435584288
# 840
# (41, 41)
# 882
# 923
# 964
# 1005
# 1046
# 1087
# 1128
# 1169
# 1210
# 1251
# 1291
# 10   10
# 1332
# 1373
# 1415
# 1416
# 1376
# 1377
# 1378
# 1379
# 1380
# node:  1028628
# minimum downstream value:  -0.596035471076
# mean upstream value:  -0.462846255899
# std upstream value:  0.0253088505358
# minimum downstream value:  -0.627687295906
# mean upstream value:  -0.446556483333
# std upstream value:  0.0160265270565
# minimum downstream value:  -0.627687295906
# mean upstream value:  -0.436160513535
# std upstream value:  0.00511330395888
# minimum downstream value:  -0.627687295906
# mean upstream value:  -0.407895918734
# std upstream value:  0.0446772133192
# minimum downstream value:  -0.582808814972
# mean upstream value:  -0.371280152493
# std upstream value:  0.0466560722171
# minimum downstream value:  -0.582808814972
# mean upstream value:  -0.303543784402
# std upstream value:  0.0496879167148
# minimum downstream value:  -0.490912999089
# mean upstream value:  -0.249537763231
# std upstream value:  0.0620304875477
# minimum downstream value:  -0.468048276637
# mean upstream value:  -0.19151948469
# std upstream value:  0.0314420270153
# 840
# (41, 41)
# 839
# 879
# 919
# 918
# 959
# 999
# 1040
# 1081
# 1122
# 1163
# 1204
# 10   10
# 1245
# 1287
# 1329
# 1369
# 1409
# 1451
# 1491
# 1532
# 1573
# node:  1059942
# minimum downstream value:  -0.835322172745
# mean upstream value:  -0.179374915966
# std upstream value:  0.004776551519
# 840
# (41, 41)
# 880
# 921
# 962
# 1003
# 1044
# 1085
# 1125
# 1166
# 1206
# 1247
# 1287
# 10   10
# 1327
# 1367
# 1407
# 1447
# 1488
# 1528
# 1569
# 1610
# 1609
# node:  1065701
# minimum downstream value:  -0.903210063226
# mean upstream value:  -0.534007538606
# std upstream value:  0.288639350739
# minimum downstream value:  -0.860064148432
# mean upstream value:  -0.270488251496
# std upstream value:  0.102509110967
# minimum downstream value:  -0.860064148432
# mean upstream value:  -0.252058408634
# std upstream value:  0.105828802775
# minimum downstream value:  -0.860064148432
# mean upstream value:  -0.155431614249
# std upstream value:  0.0449098218257
# 840
# (41, 41)
# 841
# 842
# 802
# 762
# 722
# 723
# 683
# 684
# 644
# 645
# 646
# 10   10
# 647
# 606
# 566
# 526
# 485
# 445
# 446
# 406
# 366
# node:  1146212
# minimum downstream value:  -0.727852289856
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 760
# 761
# 762
# 763
# 764
# 765
# 766
# 767
# 768
# 769
# 10   10
# 811
# 812
# 772
# 732
# 692
# 651
# 610
# 569
# 570
# node:  1147383
# minimum downstream value:  -0.431405289842
# mean upstream value:  -0.46134080246
# std upstream value:  0.0114550175217
# minimum downstream value:  -0.431405289842
# mean upstream value:  -0.441692216594
# std upstream value:  0.0331304714695
# minimum downstream value:  -0.431405289842
# mean upstream value:  -0.406747388274
# std upstream value:  0.0541078401301
# minimum downstream value:  -0.433686237561
# mean upstream value:  -0.401884669529
# std upstream value:  0.04785427257
# minimum downstream value:  -0.456397015115
# mean upstream value:  -0.423824546522
# std upstream value:  0.0553010920308
# minimum downstream value:  -0.456397015115
# mean upstream value:  -0.37699817763
# std upstream value:  0.121523191406
# minimum downstream value:  -0.477172911874
# mean upstream value:  -0.2385886372
# std upstream value:  0.171435964592
# minimum downstream value:  -0.477172911874
# mean upstream value:  -0.11143254417
# std upstream value:  0.0677362491462
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 927
# 928
# 929
# 930
# 931
# 891
# 892
# 10   10
# 893
# 894
# 936
# 937
# 938
# 939
# 899
# 900
# 941
# node:  1147673
# minimum downstream value:  -1.40381157917
# mean upstream value:  -0.00403812091812
# std upstream value:  0.00333566373116
# 840
# (41, 41)
# 800
# 760
# 719
# 679
# 639
# 599
# 559
# 560
# 561
# 562
# 563
# 10   10
# 564
# 565
# 525
# 485
# 444
# 403
# 363
# 323
# 282
# node:  1158880
# minimum downstream value:  -0.411090292949
# mean upstream value:  -0.45922526886
# std upstream value:  0.095394439942
# minimum downstream value:  -0.40909745288
# mean upstream value:  -0.399204791927
# std upstream value:  0.101460246982
# minimum downstream value:  -0.482555193392
# mean upstream value:  -0.234120284773
# std upstream value:  0.132022668332
# minimum downstream value:  -0.482555193392
# mean upstream value:  -0.127928340545
# std upstream value:  0.143294287392
# minimum downstream value:  -0.509298452747
# mean upstream value:  -0.0181826665624
# std upstream value:  0.0208797719563
# 840
# (41, 41)
# 800
# 760
# 720
# 679
# 639
# 599
# 559
# 519
# 520
# 521
# 522
# 10   10
# 523
# 524
# 525
# 485
# 445
# 404
# 363
# 323
# 283
# node:  1160309
# minimum downstream value:  -0.411090292949
# mean upstream value:  -0.50671150499
# std upstream value:  0.0304765404726
# minimum downstream value:  -0.411090292949
# mean upstream value:  -0.45922526886
# std upstream value:  0.095394439942
# minimum downstream value:  -0.40909745288
# mean upstream value:  -0.399204791927
# std upstream value:  0.101460246982
# minimum downstream value:  -0.482555193392
# mean upstream value:  -0.234120284773
# std upstream value:  0.132022668332
# minimum downstream value:  -0.482555193392
# mean upstream value:  -0.127928340545
# std upstream value:  0.143294287392
# minimum downstream value:  -0.509298452747
# mean upstream value:  -0.0181826665624
# std upstream value:  0.0208797719563
# 840
# (41, 41)
# 880
# 920
# 961
# 1001
# 1042
# 1084
# 1126
# 1167
# 1209
# 1250
# 1292
# 10   10
# 1334
# 1335
# 1377
# 1419
# 1461
# 1502
# 1542
# 1582
# 1623
# node:  1161540
# minimum downstream value:  -0.560566023876
# mean upstream value:  -0.0256083793791
# std upstream value:  0.0189580090805
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 845
# 805
# 806
# 848
# 849
# 891
# 892
# 10   10
# 893
# 853
# 854
# 855
# 856
# 898
# 858
# 859
# 900
# node:  1163384
# minimum downstream value:  -1.0601811164
# mean upstream value:  -1.19014787234
# std upstream value:  0.0183912299936
# minimum downstream value:  -1.08070536376
# mean upstream value:  -1.21146545611
# std upstream value:  0.0481081894372
# minimum downstream value:  -1.08070536376
# mean upstream value:  -1.25597433862
# std upstream value:  0.0617157585747
# minimum downstream value:  -1.16667443679
# mean upstream value:  -1.29298763753
# std upstream value:  0.0172279617955
# minimum downstream value:  -1.21518077021
# mean upstream value:  -1.30744441539
# std upstream value:  0.0177264707373
# minimum downstream value:  -1.21518077021
# mean upstream value:  -1.04377263085
# std upstream value:  0.366302750503
# minimum downstream value:  -1.21518077021
# mean upstream value:  -0.849382433181
# std upstream value:  0.341932297421
# minimum downstream value:  -1.27913352152
# mean upstream value:  -0.408547814813
# std upstream value:  0.297407825337
# minimum downstream value:  -1.31727129669
# mean upstream value:  -0.233129167117
# std upstream value:  0.329694429922
# minimum downstream value:  -1.31727129669
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 845
# 846
# 847
# 848
# 890
# 850
# 851
# 10   10
# 852
# 812
# 813
# 814
# 774
# 734
# 776
# 777
# 818
# node:  1163392
# minimum downstream value:  -1.31727129669
# mean upstream value:  -0.233129167117
# std upstream value:  0.329694429922
# minimum downstream value:  -1.31727129669
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 760
# 720
# 721
# 681
# 682
# 642
# 643
# 644
# 604
# 564
# 10   10
# 565
# 607
# 608
# 568
# 528
# 487
# 446
# 405
# 364
# node:  1197548
# minimum downstream value:  -0.43251836724
# mean upstream value:  -0.24217398019
# std upstream value:  0.118173040141
# minimum downstream value:  -0.43251836724
# mean upstream value:  -0.137092550124
# std upstream value:  0.106678663148
# minimum downstream value:  -0.390547107802
# mean upstream value:  -0.0661275509318
# std upstream value:  0.0156793506169
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 886
# 928
# 970
# 1011
# 1012
# 1013
# 1055
# 10   10
# 1097
# 1138
# 1179
# 1220
# 1261
# 1262
# 1304
# 1305
# 1306
# node:  1206139
# minimum downstream value:  -0.42502799053
# mean upstream value:  -0.320098133112
# std upstream value:  0.0812505698634
# minimum downstream value:  -0.404954631338
# mean upstream value:  -0.276678525098
# std upstream value:  0.101121756019
# minimum downstream value:  -0.404954631338
# mean upstream value:  -0.137093625678
# std upstream value:  0.0976223394056
# 840
# (41, 41)
# 880
# 838
# 796
# 795
# 794
# 793
# 792
# 832
# 873
# 914
# 955
# 10   10
# 996
# 1037
# 1078
# 1119
# 1160
# 1200
# 1240
# 1280
# 1320
# node:  1274685
# minimum downstream value:  -0.579926984583
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 883
# 843
# 844
# 845
# 846
# 806
# 848
# 849
# 809
# 810
# 10   10
# 811
# 853
# 854
# 855
# 897
# 898
# 858
# 859
# 818
# node:  1281940
# minimum downstream value:  -0.488071758285
# mean upstream value:  -0.134732292889
# std upstream value:  0.0354847778624
# 840
# (41, 41)
# 880
# 921
# 961
# 1002
# 1042
# 1083
# 1123
# 1163
# 1203
# 1244
# 1284
# 10   10
# 1325
# 1366
# 1407
# 1448
# 1489
# 1529
# 1570
# 1610
# 1611
# node:  1286125
# minimum downstream value:  -0.759550041832
# mean upstream value:  -0.0780632813143
# std upstream value:  0.0618927688837
# 840
# (41, 41)
# 800
# 760
# 720
# 721
# 722
# 723
# 724
# 725
# 726
# 768
# 769
# 10   10
# 770
# 771
# 772
# 813
# 854
# 895
# 937
# 897
# 898
# node:  1304855
# minimum downstream value:  -0.83138932541
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 759
# 718
# 719
# 679
# 680
# 640
# 599
# 558
# 517
# 477
# 10   10
# 437
# 397
# 398
# 358
# 318
# 277
# 237
# 238
# 197
# node:  1364954
# minimum downstream value:  -0.769918087443
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 760
# 761
# 762
# 763
# 764
# 806
# 807
# 767
# 727
# 687
# 10   10
# 647
# 648
# 649
# 691
# 692
# 734
# 694
# 695
# 654
# node:  1369250
# minimum downstream value:  -0.804330456398
# mean upstream value:  -0.459275860089
# std upstream value:  0.160591952723
# minimum downstream value:  -0.804330456398
# mean upstream value:  -0.266563395424
# std upstream value:  0.232924376242
# minimum downstream value:  -0.804330456398
# mean upstream value:  -0.0774161699418
# std upstream value:  0.109482997479
# minimum downstream value:  -0.776121388311
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 883
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 10   10
# 852
# 812
# 772
# 773
# 733
# 734
# 735
# 777
# 818
# node:  1377837
# minimum downstream value:  -0.850287094418
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 804
# 805
# 765
# 725
# 726
# 686
# 687
# 10   10
# 688
# 689
# 649
# 650
# 651
# 652
# 612
# 571
# 613
# node:  1388293
# minimum downstream value:  -0.486293566557
# mean upstream value:  -0.0810143190567
# std upstream value:  0.00735305215298
# 840
# (41, 41)
# 882
# 924
# 925
# 926
# 927
# 928
# 929
# 930
# 890
# 891
# 851
# 10   10
# 852
# 853
# 854
# 814
# 815
# 775
# 776
# 735
# 777
# node:  1406849
# minimum downstream value:  -0.502944644732
# mean upstream value:  -0.225675711048
# std upstream value:  0.245033163448
# minimum downstream value:  -0.502944644732
# mean upstream value:  -0.0403274918105
# std upstream value:  0.049898375972
# 840
# (41, 41)
# 882
# 883
# 884
# 885
# 886
# 887
# 847
# 848
# 808
# 809
# 810
# 10   10
# 811
# 771
# 772
# 732
# 733
# 692
# 734
# 776
# 817
# node:  1408281
# minimum downstream value:  -0.520360592326
# mean upstream value:  -0.0101328511797
# std upstream value:  0.00815225914764
# 840
# (41, 41)
# 880
# 920
# 961
# 1001
# 1042
# 1041
# 1081
# 1122
# 1163
# 1204
# 1244
# 10   10
# 1202
# 1160
# 1118
# 1076
# 1075
# 1115
# 1156
# 1155
# 1195
# node:  1416412
# minimum downstream value:  -0.321225856133
# mean upstream value:  -0.316173397662
# std upstream value:  0.0668470745695
# minimum downstream value:  -0.3169977844
# mean upstream value:  -0.301096497788
# std upstream value:  0.0858384847339
# minimum downstream value:  -0.3169977844
# mean upstream value:  -0.305435411858
# std upstream value:  0.0908504260686
# minimum downstream value:  -0.349439779289
# mean upstream value:  -0.258158737806
# std upstream value:  0.108879426291
# minimum downstream value:  -0.349439779289
# mean upstream value:  -0.216807158097
# std upstream value:  0.14464968865
# minimum downstream value:  -0.39880552028
# mean upstream value:  -0.11077530048
# std upstream value:  0.0453146170888
# 840
# (41, 41)
# 880
# 920
# 960
# 1000
# 1041
# 1040
# 1080
# 1121
# 1162
# 1203
# 1243
# 10   10
# 1201
# 1159
# 1117
# 1075
# 1074
# 1114
# 1155
# 1154
# 1194
# node:  1416413
# minimum downstream value:  -0.295951421082
# mean upstream value:  -0.316173397662
# std upstream value:  0.0668470745695
# minimum downstream value:  -0.3169977844
# mean upstream value:  -0.301096497788
# std upstream value:  0.0858384847339
# minimum downstream value:  -0.3169977844
# mean upstream value:  -0.305435411858
# std upstream value:  0.0908504260686
# minimum downstream value:  -0.349439779289
# mean upstream value:  -0.258158737806
# std upstream value:  0.108879426291
# minimum downstream value:  -0.349439779289
# mean upstream value:  -0.216807158097
# std upstream value:  0.14464968865
# minimum downstream value:  -0.39880552028
# mean upstream value:  -0.11077530048
# std upstream value:  0.0453146170888
# 840
# (41, 41)
# 880
# 921
# 920
# 960
# 1001
# 1042
# 1083
# 1123
# 1081
# 1039
# 997
# 10   10
# 955
# 954
# 994
# 1035
# 1034
# 1074
# 1116
# 1157
# 1198
# node:  1420700
# minimum downstream value:  -0.349439779289
# mean upstream value:  -0.258158737806
# std upstream value:  0.108879426291
# minimum downstream value:  -0.349439779289
# mean upstream value:  -0.216807158097
# std upstream value:  0.14464968865
# minimum downstream value:  -0.39880552028
# mean upstream value:  -0.11077530048
# std upstream value:  0.0453146170888
# 840
# (41, 41)
# 882
# 883
# 884
# 885
# 886
# 887
# 929
# 930
# 931
# 891
# 850
# 10   10
# 851
# 811
# 812
# 854
# 814
# 856
# 857
# 858
# 859
# node:  1430728
# minimum downstream value:  -0.367156258685
# mean upstream value:  -0.367977066945
# std upstream value:  0.0579076992323
# minimum downstream value:  -0.384100540825
# mean upstream value:  -0.38837114216
# std upstream value:  0.0853733654394
# minimum downstream value:  -0.410233539084
# mean upstream value:  -0.353847488584
# std upstream value:  0.124572846444
# minimum downstream value:  -0.410233539084
# mean upstream value:  -0.304029120444
# std upstream value:  0.142307773233
# minimum downstream value:  -0.444064686892
# mean upstream value:  -0.135613482931
# std upstream value:  0.0959307602982
# 840
# (41, 41)
# 800
# 759
# 718
# 678
# 637
# 596
# 555
# 513
# 471
# 470
# 469
# 10   10
# 510
# 551
# 592
# 632
# node:  1445003
# minimum downstream value:  -0.404064495102
# mean upstream value:  -0.166608506355
# std upstream value:  0.140428503692
# minimum downstream value:  -0.404064495102
# mean upstream value:  -0.0452240754179
# std upstream value:  0.0350827852368
# 840
# (41, 41)
# 882
# 924
# 925
# 926
# 968
# 969
# 1010
# 1052
# 1053
# 1054
# 1055
# 10   10
# 1097
# 1057
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# node:  1453631
# minimum downstream value:  -0.831635546779
# mean upstream value:  -0.662483396266
# std upstream value:  0.096150936021
# minimum downstream value:  -0.855808242979
# mean upstream value:  -0.567262631945
# std upstream value:  0.11830448029
# minimum downstream value:  -0.876875654982
# mean upstream value:  -0.324542059415
# std upstream value:  0.231765973215
# minimum downstream value:  -0.876875654982
# mean upstream value:  -0.149031617739
# std upstream value:  0.210762535029
# minimum downstream value:  -0.876875654982
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 799
# 759
# 719
# 720
# 762
# 763
# 764
# 806
# 807
# 767
# 768
# 10   10
# 769
# 770
# 771
# 813
# 814
# 856
# 857
# 858
# 900
# node:  1466474
# minimum downstream value:  -0.774594936446
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 842
# 884
# 885
# 886
# 846
# 806
# 766
# 725
# 685
# 645
# 10   10
# 646
# 606
# 607
# 608
# 568
# 528
# 529
# 489
# 490
# node:  1475376
# minimum downstream value:  -1.0605093613
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 883
# 884
# 926
# 927
# 969
# 1011
# 1053
# 1095
# 1096
# 1138
# 10   10
# 1139
# 1099
# 1100
# 1142
# 1143
# 1185
# 1227
# 1268
# 1310
# node:  1475407
# minimum downstream value:  -1.16979491946
# mean upstream value:  -0.00086562969625
# std upstream value:  0.00122418525643
# 840
# (41, 41)
# 800
# 760
# 802
# 844
# 845
# 846
# 806
# 766
# 726
# 685
# 645
# 10   10
# 605
# 606
# 566
# 567
# 568
# 528
# 488
# 489
# 449
# node:  1476805
# minimum downstream value:  -1.0605093613
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 842
# 802
# 803
# 763
# 805
# 806
# 848
# 849
# 891
# 933
# 10   10
# 975
# 1017
# 1018
# 1060
# 1061
# 1021
# 1022
# 1064
# 1105
# node:  1478263
# minimum downstream value:  -1.10276532079
# mean upstream value:  -0.948444984647
# std upstream value:  0.187120711593
# minimum downstream value:  -1.12750636165
# mean upstream value:  -0.571011036909
# std upstream value:  0.425604617717
# minimum downstream value:  -1.16979491946
# mean upstream value:  -0.230562383478
# std upstream value:  0.326064449688
# minimum downstream value:  -1.16979491946
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 923
# 964
# 1006
# 1047
# 1089
# 1130
# 1171
# 1213
# 1254
# 1295
# 10   10
# 1336
# 1378
# 1419
# 1461
# 1502
# 1543
# 1584
# 1625
# 1626
# node:  1485410
# minimum downstream value:  -0.758806824213
# mean upstream value:  -0.012153444554
# std upstream value:  0.00609538130233
# 840
# (41, 41)
# 800
# 760
# 720
# 679
# 680
# 681
# 641
# 600
# 559
# 519
# 479
# 10   10
# 480
# 439
# 399
# 358
# 318
# 319
# 320
# 321
# 281
# node:  1509656
# minimum downstream value:  -0.678620229125
# mean upstream value:  -0.19134598884
# std upstream value:  0.236889504328
# minimum downstream value:  -0.678620229125
# mean upstream value:  -0.0162899635526
# std upstream value:  0.0230374873867
# 840
# (41, 41)
# 800
# 801
# 802
# 803
# 804
# 846
# 847
# 888
# 930
# 931
# 890
# 10   10
# 850
# 851
# 852
# 853
# 813
# 773
# 733
# 693
# 653
# node:  1576628
# minimum downstream value:  -0.364225847448
# mean upstream value:  -0.347704991679
# std upstream value:  0.0514766895977
# minimum downstream value:  -0.366299293729
# mean upstream value:  -0.329371064077
# std upstream value:  0.0255928761351
# minimum downstream value:  -0.403041824522
# mean upstream value:  -0.363298298028
# std upstream value:  0.043698276851
# minimum downstream value:  -0.403041824522
# mean upstream value:  -0.404956581407
# std upstream value:  0.0288922991561
# minimum downstream value:  -0.420442272081
# mean upstream value:  -0.383815740251
# std upstream value:  0.0583047350895
# minimum downstream value:  -0.420442272081
# mean upstream value:  -0.288886672109
# std upstream value:  0.123960884857
# minimum downstream value:  -0.420442272081
# mean upstream value:  -0.144315013458
# std upstream value:  0.123661205445
# minimum downstream value:  -0.365440489275
# mean upstream value:  -0.0436423581894
# std upstream value:  0.0617196148453
# 840
# (41, 41)
# 882
# 924
# 966
# 1008
# 1050
# 1051
# 1091
# 1090
# 1130
# 1170
# 1211
# 10   10
# 1253
# 1294
# 1336
# 1378
# 1420
# 1462
# 1503
# 1545
# 1587
# node:  1579431
# minimum downstream value:  -0.458394680099
# mean upstream value:  -0.246661049261
# std upstream value:  0.180734994596
# minimum downstream value:  -0.483262465405
# mean upstream value:  -0.103990145195
# std upstream value:  0.147064273687
# minimum downstream value:  -0.572854445386
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 842
# 843
# 803
# 762
# 722
# 681
# 641
# 600
# 559
# 519
# 10   10
# 478
# 438
# 397
# 357
# 317
# 359
# 360
# 361
# 403
# node:  1592313
# minimum downstream value:  -0.755331318369
# mean upstream value:  -0.60517340498
# std upstream value:  0.0173472846791
# minimum downstream value:  -0.756316324468
# mean upstream value:  -0.591669828995
# std upstream value:  0.0363022422828
# minimum downstream value:  -0.756316324468
# mean upstream value:  -0.574742333534
# std upstream value:  0.0299742321264
# minimum downstream value:  -0.756316324468
# mean upstream value:  -0.546336388871
# std upstream value:  0.0175979348132
# minimum downstream value:  -0.68998498125
# mean upstream value:  -0.593263608508
# std upstream value:  0.064555432692
# minimum downstream value:  -0.68998498125
# mean upstream value:  -0.594664351271
# std upstream value:  0.0640837253065
# minimum downstream value:  -0.620985400535
# mean upstream value:  -0.619551677478
# std upstream value:  0.0451875593925
# minimum downstream value:  -0.620985400535
# mean upstream value:  -0.507081404976
# std upstream value:  0.115985709479
# minimum downstream value:  -0.613511730089
# mean upstream value:  -0.327917578977
# std upstream value:  0.23136136481
# minimum downstream value:  -0.570202914151
# mean upstream value:  -0.126932287405
# std upstream value:  0.154145878498
# minimum downstream value:  -0.681294015274
# mean upstream value:  -0.0123045548149
# std upstream value:  0.0174012682982
# 840
# (41, 41)
# 841
# 842
# 802
# 761
# 721
# 680
# 640
# 599
# 558
# 518
# 477
# 10   10
# 437
# 396
# 356
# 316
# 358
# 359
# 360
# 402
# 362
# node:  1592314
# minimum downstream value:  -0.756316324468
# mean upstream value:  -0.591669828995
# std upstream value:  0.0363022422828
# minimum downstream value:  -0.756316324468
# mean upstream value:  -0.574742333534
# std upstream value:  0.0299742321264
# minimum downstream value:  -0.756316324468
# mean upstream value:  -0.546336388871
# std upstream value:  0.0175979348132
# minimum downstream value:  -0.68998498125
# mean upstream value:  -0.593263608508
# std upstream value:  0.064555432692
# minimum downstream value:  -0.68998498125
# mean upstream value:  -0.594664351271
# std upstream value:  0.0640837253065
# minimum downstream value:  -0.620985400535
# mean upstream value:  -0.619551677478
# std upstream value:  0.0451875593925
# minimum downstream value:  -0.620985400535
# mean upstream value:  -0.507081404976
# std upstream value:  0.115985709479
# minimum downstream value:  -0.613511730089
# mean upstream value:  -0.327917578977
# std upstream value:  0.23136136481
# minimum downstream value:  -0.570202914151
# mean upstream value:  -0.126932287405
# std upstream value:  0.154145878498
# minimum downstream value:  -0.681294015274
# mean upstream value:  -0.0123045548149
# std upstream value:  0.0174012682982
# 840
# (41, 41)
# 880
# 920
# 960
# 1000
# 1041
# 1081
# 1122
# 1163
# 1203
# 1244
# 1285
# 10   10
# 1325
# 1365
# 1364
# 1405
# 1446
# 1487
# 1528
# 1569
# 1609
# node:  1605124
# minimum downstream value:  -0.543614323431
# mean upstream value:  -0.0494549817876
# std upstream value:  0.0133721695326
# 840
# (41, 41)
# 882
# 924
# 966
# 1008
# 1009
# 1051
# 1093
# 1134
# 1176
# 1177
# 1219
# 10   10
# 1179
# 1221
# 1262
# 1263
# 1304
# 1346
# 1388
# 1430
# 1471
# node:  1625392
# minimum downstream value:  -0.875679830317
# mean upstream value:  -0.253288228835
# std upstream value:  0.0937440482054
# minimum downstream value:  -0.875679830317
# mean upstream value:  -0.163272581239
# std upstream value:  0.0983449758078
# 840
# (41, 41)
# 882
# 924
# 925
# 967
# 1009
# 1050
# 1092
# 1093
# 1135
# 1095
# 1137
# 10   10
# 1178
# 1179
# 1220
# 1262
# 1304
# 1346
# 1387
# 1428
# 1470
# node:  1628254
# minimum downstream value:  -0.875679830317
# mean upstream value:  -0.0874423402728
# std upstream value:  0.0249618880946
# 840
# (41, 41)
# 882
# 923
# 964
# 1005
# 1046
# 1086
# 1127
# 1167
# 1208
# 1249
# 1289
# 10   10
# 1330
# 1371
# 1413
# 1414
# 1456
# 1457
# 1499
# 1500
# 1501
# node:  1648182
# minimum downstream value:  -0.348917030063
# mean upstream value:  -0.341890588894
# std upstream value:  0.00521880346431
# minimum downstream value:  -0.365385636039
# mean upstream value:  -0.342246788135
# std upstream value:  0.00561653721295
# minimum downstream value:  -0.384436324651
# mean upstream value:  -0.35700832965
# std upstream value:  0.0222009045868
# minimum downstream value:  -0.384436324651
# mean upstream value:  -0.355758325227
# std upstream value:  0.0234751988487
# minimum downstream value:  -0.384436324651
# mean upstream value:  -0.329545444494
# std upstream value:  0.0479358904874
# minimum downstream value:  -0.34758378583
# mean upstream value:  -0.279856062375
# std upstream value:  0.0385589364828
# minimum downstream value:  -0.34758378583
# mean upstream value:  -0.22547729653
# std upstream value:  0.0425907456113
# minimum downstream value:  -0.348652383556
# mean upstream value:  -0.198959983856
# std upstream value:  0.0292973324567
# minimum downstream value:  -0.387396107549
# mean upstream value:  -0.127233040349
# std upstream value:  0.0741643658761
# 840
# (41, 41)
# 882
# 923
# 964
# 1006
# 1047
# 1088
# 1129
# 1171
# 1213
# 1254
# 1295
# 10   10
# 1335
# 1375
# 1415
# 1414
# 1454
# 1453
# 1452
# 1492
# 1533
# node:  1709652
# minimum downstream value:  -0.371844717636
# mean upstream value:  -0.329247676965
# std upstream value:  0.0507575368037
# minimum downstream value:  -0.371844717636
# mean upstream value:  -0.283229249896
# std upstream value:  0.0336781815452
# minimum downstream value:  -0.377065877198
# mean upstream value:  -0.232033831329
# std upstream value:  0.0395923554499
# minimum downstream value:  -0.377065877198
# mean upstream value:  -0.143161959642
# std upstream value:  0.105911652198
# minimum downstream value:  -0.390934910228
# mean upstream value:  -0.0588687499678
# std upstream value:  0.0832529846045
# 840
# (41, 41)
# 882
# 923
# 964
# 1005
# 1047
# 1089
# 1130
# 1171
# 1211
# 1251
# 1291
# 10   10
# 1290
# 1330
# 1329
# 1328
# 1368
# 1409
# 1449
# 1489
# 1488
# node:  1713943
# minimum downstream value:  -0.377065877198
# mean upstream value:  -0.143161959642
# std upstream value:  0.105911652198
# minimum downstream value:  -0.390934910228
# mean upstream value:  -0.0588687499678
# std upstream value:  0.0832529846045
# 840
# (41, 41)
# 841
# 842
# 884
# 885
# 927
# 968
# 1010
# 1011
# 1012
# 972
# 1014
# 10   10
# 974
# 934
# 894
# 895
# 896
# 897
# 898
# 899
# 859
# node:  1844350
# minimum downstream value:  -0.432701864733
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 922
# 962
# 1003
# 1044
# 1086
# 1127
# 1168
# 1210
# 1211
# 1253
# 10   10
# 1295
# 1337
# 1379
# 1380
# 1421
# 1463
# 1504
# 1546
# 1547
# node:  1855790
# minimum downstream value:  -0.348368769107
# mean upstream value:  -0.0118082823018
# std upstream value:  0.00861764819007
# 840
# (41, 41)
# 882
# 924
# 966
# 1007
# 1049
# 1050
# 1092
# 1133
# 1175
# 1217
# 1218
# 10   10
# 1178
# 1179
# 1180
# 1181
# 1141
# 1183
# 1143
# 1144
# 1186
# node:  1878690
# minimum downstream value:  -0.63584058558
# mean upstream value:  -0.176893794647
# std upstream value:  0.174288774969
# minimum downstream value:  -0.63584058558
# mean upstream value:  -0.0388974779051
# std upstream value:  0.0550093407955
# 840
# (41, 41)
# 800
# 801
# 802
# 844
# 886
# 887
# 888
# 889
# 890
# 932
# 974
# 10   10
# 975
# 1017
# 1018
# 1059
# 1101
# 1143
# 1185
# 1227
# 1269
# node:  1902936
# minimum downstream value:  -0.566328176868
# mean upstream value:  -0.141044526232
# std upstream value:  0.17228825862
# minimum downstream value:  -0.566328176868
# mean upstream value:  -0.0131688777637
# std upstream value:  0.0186236055347
# 840
# (41, 41)
# 882
# 883
# 925
# 926
# 968
# 969
# 1011
# 1053
# 1095
# 1137
# 1138
# 10   10
# 1139
# 1140
# 1182
# 1224
# 1265
# 1307
# 1308
# 1350
# 1392
# node:  1912926
# minimum downstream value:  -0.463970681895
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 923
# 964
# 1006
# 1048
# 1089
# 1090
# 1091
# 1133
# 1134
# 1176
# 10   10
# 1136
# 1137
# 1179
# 1180
# 1221
# 1263
# 1264
# 1306
# 1348
# node:  1912941
# minimum downstream value:  -0.417207137398
# mean upstream value:  0.0
# std upstream value:  0.0

# %%
final_gully_heads
# Out:
# {320908: 319484,
#  325215: 322361,
#  413660: 406515,
#  416514: 407945,
#  486729: 493886,
#  509646: 498215,
#  554171: 547027,
#  565479: 574059,
#  567093: 564239,
#  568456: 564171,
#  572542: 585426,
#  581131: 586856,
#  585687: 585693,
#  595681: 604260,
#  598545: 607131,
#  619970: 624265,
#  821130: 835425,
#  835453: 844033,
#  874037: 892621,
#  945521: 946945,
#  957407: 955984,
#  957408: 955984,
#  981264: 984113,
#  1004150: 1009880,
#  1018442: 1018433,
#  1028628: 1047218,
#  1059942: 1065657,
#  1065701: 1078568,
#  1146212: 1141928,
#  1147383: 1145966,
#  1147673: 1150539,
#  1158880: 1148879,
#  1160309: 1148879,
#  1161540: 1170118,
#  1163384: 1163399,
#  1163392: 1163399,
#  1197548: 1190406,
#  1206139: 1211866,
#  1274685: 1273249,
#  1281940: 1281946,
#  1286125: 1294702,
#  1304855: 1300571,
#  1364954: 1359238,
#  1369250: 1366399,
#  1377837: 1379273,
#  1388293: 1386869,
#  1406849: 1409716,
#  1408281: 1409717,
#  1416412: 1430706,
#  1416413: 1430706,
#  1420700: 1430706,
#  1430728: 1432168,
#  1445003: 1434995,
#  1453631: 1460790,
#  1466474: 1463619,
#  1475376: 1475382,
#  1475407: 1479703,
#  1476805: 1476811,
#  1478263: 1478272,
#  1485410: 1493993,
#  1509656: 1502512,
#  1576628: 1576639,
#  1579431: 1588015,
#  1592313: 1573733,
#  1592314: 1573733,
#  1605124: 1613699,
#  1625392: 1633979,
#  1628254: 1635409,
#  1648182: 1668201,
#  1709652: 1723956,
#  1713943: 1723956,
#  1844350: 1848645,
#  1855790: 1864370,
#  1878690: 1887276,
#  1902936: 1904373,
#  1912926: 1917222,
#  1912941: 1921524}

# %%
def get_values(my_dict):
    gullies_to_keep = []
    for key, value in my_dict.items():
        gullies_to_keep.append(value)
    return gullies_to_keep

# %%
final_gullies = get_values(final_gully_heads)

# %%
final_gully_head_nodes = np.isin(grid_nodes,final_gullies).astype('uint8')

# %%
len(final_gully_heads)
# Out:
# 77

# %%
def get_key(val, my_dict):
    gullies_to_keep = []
    for key, value in my_dict.items(): 
         if val == value:
                gullies_to_keep.append(key)
    return gullies_to_keep

# %% [markdown]
# ### Check that the new list finding exact gully head position is the same length as the list of gully heads to keep.

# %%
gullies_to_keep_node_list = get_key('yes', gully_head_dict)

# %%
len(gullies_to_keep_node_list)
# Out:
# 77

# %% [markdown]
# # Examine a single gully head

# %%
def singleUpstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
                
        grid_nodes_subset = grid_nodes[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        
        flattened_grid_nodes_subset = grid_nodes_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        original_node_id_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                initial_node_id = catchment_outlet_id
                print('initial id: ', initial_node_id)
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            upstream_original_node_id = {}
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        original_node_id = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_grid_nodes_subset))
                        upstream_original_node_id.update({node_id_value:original_node_id})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    original_node_id_dict[primary_flow_direction_id] = upstream_original_node_id[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)
        
        for key, value in node_dfme_dict.items():
            print('nodes in dict: ', key)
            
        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        original_node_id_along_central_drainage_line = []
        for key, value in original_node_id_dict.items():
            original_node_id_along_central_drainage_line.append(value)
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            divergence_occuring = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            upslope_divergence_dict[i] = divergence_occuring
    

    
    return original_node_id_along_central_drainage_line, slope_along_central_drainage_line,dfme_along_central_drainage_line

# %%
start_time = timeit.default_timer()
catchment_outlet_id = [1158880]
node_drainage_line, slope_values, dfme_values = singleUpstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,catchment_outlet_id, 3, 3, 10, -0.2, -0.2)
timeit.default_timer() - start_time
# Out:
# 840
# (41, 41)
# initial id:  840
# nodes in dict:  800
# nodes in dict:  760
# nodes in dict:  719
# nodes in dict:  679
# nodes in dict:  639
# nodes in dict:  599
# nodes in dict:  559
# nodes in dict:  560
# nodes in dict:  561
# nodes in dict:  562
# nodes in dict:  563
# nodes in dict:  564
# nodes in dict:  565
# nodes in dict:  525
# nodes in dict:  485
# nodes in dict:  444
# nodes in dict:  403
# nodes in dict:  363
# nodes in dict:  323
# nodes in dict:  282
# minimum downstream value:  -0.411090292949
# mean upstream value:  -0.45922526886
# std upstream value:  0.095394439942
# minimum downstream value:  -0.40909745288
# mean upstream value:  -0.399204791927
# std upstream value:  0.101460246982
# minimum downstream value:  -0.482555193392
# mean upstream value:  -0.234120284773
# std upstream value:  0.132022668332
# minimum downstream value:  -0.482555193392
# mean upstream value:  -0.127928340545
# std upstream value:  0.143294287392
# minimum downstream value:  -0.509298452747
# mean upstream value:  -0.0181826665624
# std upstream value:  0.0208797719563
# 0.19229880000057165

# %%
node_location = mg.nodes.reshape(da.shape)

# %%
preliminary_width = np.isin(node_location,node_drainage_line).reshape(mg.shape)

# %%
gully_drainage_values_dict = dict(zip(node_drainage_line, slope_values))

# %%
slope_drainage_values_dict = dict(zip(node_drainage_line, slope_values))
dfme_drainage_values_dict = dict(zip(node_drainage_line, dfme_values))

ds = [slope_drainage_values_dict, dfme_drainage_values_dict]
d = {}
for k in slope_drainage_values_dict.keys():
    d[k] = tuple(d[k] for d in ds) 

new_drainage_parameters = pd.DataFrame.from_dict(d, orient='index')
new_drainage_parameters.rename(columns={0:'Slope', 1:'DFME'}, inplace=True)
new_drainage_parameters.insert(0, "Distance", 0);
for i in range(0, distance_from_outlet):
    new_drainage_parameters.iloc[i,0] = i
new_drainage_parameters['Node ID'] = new_drainage_parameters.index

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
data = new_drainage_parameters

y1 = "Slope"
y2 = "DFME"

sns.lineplot(data = data,x = "Distance",y = y1, color = 'xkcd:cobalt blue')
ax1.set_ylabel(y1, fontsize=15)
ax1.lines[0].set_linestyle("--")
ax1.set_ylim(0, 0.5)
ax1.set_xlabel('Distance upstream of convergence point (m)', fontsize = 15)
ax1.legend([y1],bbox_to_anchor=(0.3, 0.21, 0.53, 0.6))
ax2 = ax1.twinx()

ax2.set_ylim(-1, 1)
sns.lineplot(data=data,x = "Distance",y=y2,color='xkcd:forest green',ax = ax2)
ax2.set_ylabel(y2, fontsize = 15)
#ax2.lines[0].set_linestyle("--")
ax2.legend([y2],bbox_to_anchor=(0.3, 0.5, 0.5, 0.4))
#plt.axvline(x=17, color = 'xkcd:merlot', linestyle = 'dotted')
#plt.axvline(x=20, color = 'xkcd:merlot', linestyle = 'dotted')
plt.axhline(y=0, color = 'xkcd:merlot', linestyle = 'dotted')
#ax1.text(18, -0.8, r'Gully head', fontsize=15, rotation = 90)
plt.title('Change in upstream values for DFME', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Change in upstream values for DFME')

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('testl2.tif', input_geotiff, preliminary_width, drainage_area.dtype)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
